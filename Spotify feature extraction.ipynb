# %% [markdown]
# Setting the API key

# %%
user = 'b9b651fbd22c4b1eaf56dbfbf3dc3e27'
api_key = 'f39c2277e4ec4b838ee55ab6d75a29fa'

# %% [markdown]
# Importing required work libaries

# %%
import random
import requests
import pandas as pd
from bs4 import BeautifulSoup
from random import randint
from time import sleep
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Creating the spotify credentials and assigning them to a spotify object
credentials = SpotifyClientCredentials(client_id=user, client_secret=api_key)
spt = spotipy.Spotify(client_credentials_manager = credentials)

# %%
playlist_link = "https://open.spotify.com/playlist/3ejmoWskEJ7n4RwivSR3ne"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
# track_uris = [x["track"]["uri"] for x in spt.playlist_tracks(playlist_URI)["items"]]

# %%
for track in spt.playlist_tracks(playlist_URI)["items"]:
    #URI
    track_uri = track["track"]["uri"]
    
    #Track name
    track_name = track["track"]["name"]
    
    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = spt.artist(artist_uri)
    
    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_genres = artist_info["genres"]
    
    #Album
    album = track["track"]["album"]["name"]
    
    #Popularity of the track
    track_pop = track["track"]["popularity"]
    
    display(spt.audio_features(track_uri)[0])
# Out:
# {'danceability': 0.506,
#  'energy': 0.766,
#  'key': 7,
#  'loudness': -8.242,
#  'mode': 1,
#  'speechiness': 0.0304,
#  'acousticness': 0.0434,
#  'instrumentalness': 0.161,
#  'liveness': 0.27,
#  'valence': 0.611,
#  'tempo': 112.64,
#  'type': 'audio_features',
#  'id': '5Ci3b8pfpLA9Zk17qGXBCF',
#  'uri': 'spotify:track:5Ci3b8pfpLA9Zk17qGXBCF',
#  'track_href': 'https://api.spotify.com/v1/tracks/5Ci3b8pfpLA9Zk17qGXBCF',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Ci3b8pfpLA9Zk17qGXBCF',
#  'duration_ms': 217360,
#  'time_signature': 4}
# {'danceability': 0.71,
#  'energy': 0.808,
#  'key': 4,
#  'loudness': -4.948,
#  'mode': 0,
#  'speechiness': 0.0588,
#  'acousticness': 0.00684,
#  'instrumentalness': 0,
#  'liveness': 0.0757,
#  'valence': 0.566,
#  'tempo': 107.02,
#  'type': 'audio_features',
#  'id': '5FA3Ol5lvJd7Xizxo1uR05',
#  'uri': 'spotify:track:5FA3Ol5lvJd7Xizxo1uR05',
#  'track_href': 'https://api.spotify.com/v1/tracks/5FA3Ol5lvJd7Xizxo1uR05',
# ...

# %%
artist_genres
# Out:
# ['reggaeton', 'reggaeton flow', 'trap latino']

# %%
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
spt.playlist_tracks(playlist_URI)["items"]
# Out:
# [{'added_at': '2021-04-05T09:45:43Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ew44z704yxhb5i3qzo36jrf7m'},
#    'href': 'https://api.spotify.com/v1/users/ew44z704yxhb5i3qzo36jrf7m',
#    'id': 'ew44z704yxhb5i3qzo36jrf7m',
#    'type': 'user',
#    'uri': 'spotify:user:ew44z704yxhb5i3qzo36jrf7m'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
# ...
